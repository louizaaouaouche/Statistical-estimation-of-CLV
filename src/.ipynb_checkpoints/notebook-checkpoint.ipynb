# %% [markdown]
# # Customer Lifetime Value (CLV) estimators

# %% [markdown]
# **Authors :**
# * Louiza AOUAOUCHE
# * Salim ABDOU DAOURA

# %% [markdown]
# **DESCRIPTION:**
#
# The project consists in studying basic estimators so as to predict the potential duration that a customer could live in a company before churning. We define it as its lifetime value. For that, we use two type of data :
# * Not censored data : means that at the moment of the measure, all the durations are known
# * Censored data (more realistic): means that, for some customers, the duration is unknown since they are still in the company. (Their lifetimes will be equal to their seniority values in the company - ancienneté in french)
#
# We use estimators based on three distributions because of their similarity with the survival function:
# * **[Geometric distribution](./geometric.ipynb)**
# * **[Exponential distribution](./exponential.ipynb)**
# * **[Pareto distribution](./pareto.ipynb)**

# %% [markdown]
# Once we studied the consistency of our estimators on randomly generated data, we apply the result on real data. For that we use a dataset from the package `sksurv.datasets` called `The Veterans’ Administration Lung Cancer Trial` which is a randomized trial of two treatment regimens for lung cancer. The data set (Kalbfleisch J. and Prentice R, (1980) The Statistical Analysis of Failure Time Data. New York: Wiley) consists of 137 patients and 8 variables, which are described below:
#
# * **Treatment**: denotes the type of lung cancer treatment; standard and test drug.
# * **Celltype**: denotes the type of cell involved; squamous, small cell, adeno, large.
# * **Karnofsky_score**: is the Karnofsky score.
# * **Diag**: is the time since diagnosis in months.
# * **Age**: is the age in years.
# * **Prior_Therapy**: denotes any prior therapy; none or yes.
# * <span style="color:blue">**Status**</span>: denotes the status of the patient as dead or alive; dead or alive.
# * <span style="color:blue">**Survival_in_days**</span>: is the survival time in days since the treatment.
# ([source](https://scikit-survival.readthedocs.io/en/stable/user_guide/00-introduction.html#The-Veterans%E2%80%99-Administration-Lung-Cancer-Trial))
#
# Our interest is to study how our estimators act on this datasets. For this we only use `Survival_in_days` and `Status` features.

# %% [markdown]
# # Real data

# %%
# imports
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import scipy.interpolate as spi
import functions as f
from sksurv.datasets import load_veterans_lung_cancer

# %%
# loading the dataset
data_x, data_y = load_veterans_lung_cancer()

status = data_y['Status']

Y = data_y['Survival_in_days']

# %%
# Plot the distribution of durations as a histogram with the interpolated line
sns.histplot(Y, color='gray', kde=False, stat='density', zorder=1).set(title="Veterans lung cancer - survival durations")
plt.xlabel("Durations (days)")
# Compute the histogram
hist, bin_edges = np.histogram(Y, density=True)

# Plot the interpolated line
bin_midpoints = (bin_edges[:-1] + bin_edges[1:]) / 2 # Compute the midpoints of the bins
spline = spi.splrep(bin_midpoints, hist) # Perform spline interpolation
x = np.linspace(min(bin_midpoints), max(bin_midpoints), 100) # Generate x values for the interpolated line
y = spi.splev(x, spline) # Evaluate the interpolated line
plt.plot(x, y, color='red', label='Real data distribution', zorder=2)

# %%
# computing 
clv_geom_c_r = f.geom_c_clv_estimator2(Y, status)
clv_exp_c_r = f.exp_c_clv_estimator2(Y , status)
clv_pareto_c_r = f.pareto_c_clv_estimator2(Y, status)

# %%
# Compare the estimators
print("Estimator Comparison:")
print("Geometric CLV Estimator:", clv_geom_c_r)
print("Exponential CLV Estimator:", clv_exp_c_r)
print("Pareto CLV Estimator:", clv_pareto_c_r)
# Out:
# Estimator Comparison:
# Geometric CLV Estimator: 130.1796875
# Exponential CLV Estimator: 130.1796875
# Pareto CLV Estimator: -0.29575575369714924

# %%
# Plot the distribution of durations as a histogram with the interpolated line
sns.histplot(Y, color='gray', kde=False, stat='density', zorder=1)

# Compute the histogram
hist, bin_edges = np.histogram(Y, density=True)

# Plot the interpolated line
bin_midpoints = (bin_edges[:-1] + bin_edges[1:]) / 2 # Compute the midpoints of the bins
spline = spi.splrep(bin_midpoints, hist) # Perform spline interpolation
x = np.linspace(min(bin_midpoints), max(bin_midpoints), 100) # Generate x values for the interpolated line
y = spi.splev(x, spline) # Evaluate the interpolated line
plt.plot(x, y, color='red', label='Real data distribution', zorder=2)

# Compute the exponential distribution values using the parameter lambda

theta_exp = 1 / clv_exp_c_r # Compute the corresponding parameter lambda
x_exp = np.linspace(0, max(Y), len(Y)) # Generate x values
exponential_dist = theta_exp * np.exp(-theta_exp * x_exp)
plt.plot(x_exp, exponential_dist,color ='blue', label=f'Estimation - exp (lambda={theta_exp:.2f})')

# Compute the Pareto distribution values using the parameters
x_m = 1  # Minimum value
theta = clv_pareto_c_r / (clv_pareto_c_r - 1)  # Shape parameter
x_pareto = np.linspace(0, max(Y), len(Y)) # Generate x values for the Pareto distribution
pareto_dist = (theta * (x_m ** theta)) / (x_pareto ** (theta + 1))
plt.plot(x_pareto, pareto_dist,color ='orange', label=f'Pareto Distribution (theta={theta:.2f})')

plt.title("Veterans lung cancer - survival durations")
plt.xlabel("Durations (days)")
plt.ylabel("Probability Density")
plt.legend()
plt.show()
# Out:
# C:\Users\louiz\AppData\Local\Temp\ipykernel_32200\2022261905.py:25: RuntimeWarning: divide by zero encountered in true_divide
#   pareto_dist = (theta * (x_m ** theta)) / (x_pareto ** (theta + 1))

# %%
np.linspace(0, max(Y), len(Y))
# Out:
# array([  0.        ,   7.34558824,  14.69117647,  22.03676471,
#         29.38235294,  36.72794118,  44.07352941,  51.41911765,
#         58.76470588,  66.11029412,  73.45588235,  80.80147059,
#         88.14705882,  95.49264706, 102.83823529, 110.18382353,
#        117.52941176, 124.875     , 132.22058824, 139.56617647,
#        146.91176471, 154.25735294, 161.60294118, 168.94852941,
#        176.29411765, 183.63970588, 190.98529412, 198.33088235,
#        205.67647059, 213.02205882, 220.36764706, 227.71323529,
#        235.05882353, 242.40441176, 249.75      , 257.09558824,
#        264.44117647, 271.78676471, 279.13235294, 286.47794118,
#        293.82352941, 301.16911765, 308.51470588, 315.86029412,
#        323.20588235, 330.55147059, 337.89705882, 345.24264706,
#        352.58823529, 359.93382353, 367.27941176, 374.625     ,
#        381.97058824, 389.31617647, 396.66176471, 404.00735294,
#        411.35294118, 418.69852941, 426.04411765, 433.38970588,
#        440.73529412, 448.08088235, 455.42647059, 462.77205882,
#        470.11764706, 477.46323529, 484.80882353, 492.15441176,
#        499.5       , 506.84558824, 514.19117647, 521.53676471,
#        528.88235294, 536.22794118, 543.57352941, 550.91911765,
#        558.26470588, 565.61029412, 572.95588235, 580.30147059,
#        587.64705882, 594.99264706, 602.33823529, 609.68382353,
#        617.02941176, 624.375     , 631.72058824, 639.06617647,
#        646.41176471, 653.75735294, 661.10294118, 668.44852941,
#        675.79411765, 683.13970588, 690.48529412, 697.83088235,
#        705.17647059, 712.52205882, 719.86764706, 727.21323529,
#        734.55882353, 741.90441176, 749.25      , 756.59558824,
#        763.94117647, 771.28676471, 778.63235294, 785.97794118,
#        793.32352941, 800.66911765, 808.01470588, 815.36029412,
#        822.70588235, 830.05147059, 837.39705882, 844.74264706,
#        852.08823529, 859.43382353, 866.77941176, 874.125     ,
#        881.47058824, 888.81617647, 896.16176471, 903.50735294,
#        910.85294118, 918.19852941, 925.54411765, 932.88970588,
#        940.23529412, 947.58088235, 954.92647059, 962.27205882,
#        969.61764706, 976.96323529, 984.30882353, 991.65441176,
#        999.        ])
